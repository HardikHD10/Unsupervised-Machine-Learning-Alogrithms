# %%
# Generalized Code for UMAP (Uniform Manifold Approximation and Projection)

# 1. Importing Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import umap.umap_ as umap
from sklearn.datasets import load_digits

# 2. Generating Sample Data (This is a placeholder, replace with your dataset loading function)
def generate_data():
    data = load_digits()
    return pd.DataFrame(data.data), data.target

# 3. UMAP Function
def perform_umap(data, n_neighbors=15, min_dist=0.1, n_components=2, random_state=42):
    reducer = umap.UMAP(n_neighbors=n_neighbors, min_dist=min_dist, n_components=n_components, random_state=random_state)
    transformed_data = reducer.fit_transform(data)
    return transformed_data

# 4. Visualization Function
def visualize_umap(transformed_data, labels):
    plt.scatter(transformed_data[:, 0], transformed_data[:, 1], c=labels, cmap='rainbow')
    plt.xlabel('UMAP Component 1')
    plt.ylabel('UMAP Component 2')
    plt.title("UMAP Result")
    plt.colorbar()
    plt.show()

# 5. Main Execution
if __name__ == "__main__":
    data, labels = generate_data()
    transformed_data = perform_umap(data)
    visualize_umap(transformed_data, labels)

    min_dist=min_dist, n_components=n_components, random_state=random_state)
    transformed_data = reducer.fit_transform(data)
    return transformed_data

# 4. Visualization Function
def visualize_umap(transformed_data, labels):
    plt.scatter(transformed_data[:, 0], transformed_data[:, 1], c=labels, cmap='rainbow')
    plt.xlabel('UMAP Component 1')
    plt.ylabel('UMAP Component 2')
    plt.title("UMAP Result")
    plt.colorbar()
    plt.show()

# 5. Main Execution
if __name__ == "__main__":
    data, labels = generate_data()
    transformed_data = perform_umap(data)
    visualize_umap(transformed_data, labels)
