# %%
# Generalized Code for PCA (Principal Component Analysis)

# 1. Importing Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.datasets import load_iris

# 2. Generating Sample Data (This is a placeholder, replace with your dataset loading function)
def generate_data():
    data = load_iris()
    return pd.DataFrame(data.data, columns=data.feature_names)

# 3. PCA Function
def perform_pca(data, n_components=2):
    pca = PCA(n_components=n_components)
    transformed_data = pca.fit_transform(data)
    return transformed_data, pca

# 4. Visualization Function
def visualize_pca(transformed_data):
    plt.scatter(transformed_data[:, 0], transformed_data[:, 1])
    plt.xlabel('Principal Component 1')
    plt.ylabel('Principal Component 2')
    plt.title("PCA Result")
    plt.show()

# 5. Main Execution
if __name__ == "__main__":
    data = generate_data()
    transformed_data, pca_model = perform_pca(data)
    visualize_pca(transformed_data)
