# %%
# Generalized Code for Hierarchical Clustering

# 1. Importing Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering
from sklearn.datasets import make_blobs

# 2. Generating Sample Data (This is a placeholder, replace with your dataset loading function)
def generate_data(n_samples=300, n_features=2, centers=4, random_state=42):
    data, _ = make_blobs(n_samples=n_samples, n_features=n_features, centers=centers, random_state=random_state)
    return pd.DataFrame(data)

# 3. Hierarchical Clustering Dendrogram
def plot_dendrogram(data, method='ward'):
    plt.figure(figsize=(10, 7))
    dendrogram = sch.dendrogram(sch.linkage(data, method=method))
    plt.title("Hierarchical Clustering Dendrogram")
    plt.show()

# 4. Hierarchical Clustering Function
def perform_hierarchical_clustering(data, n_clusters=4, affinity='euclidean', linkage='ward'):
    hc = AgglomerativeClustering(n_clusters=n_clusters, affinity=affinity, linkage=linkage)
    labels = hc.fit_predict(data)
    return labels

# 5. Visualization Function
def visualize_clusters(data, labels):
    plt.scatter(data.iloc[:, 0], data.iloc[:, 1], c=labels, cmap='rainbow')
    plt.title("Hierarchical Clustering")
    plt.show()

# 6. Main Execution
if __name__ == "__main__":
    data = generate_data()
    plot_dendrogram(data)
    labels = perform_hierarchical_clustering(data)
    visualize_clusters(data, labels)
